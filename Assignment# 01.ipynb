# %% [markdown]
# # Question#01

# %%
name ="Anas Kaleem"
Age = "22"
course = "Ai & Data Science"
institute = "Salyani"

print("name:", name)
print("Age:", Age)
print("course:", course)
print("institute:", institute)
# Out:
# name: Anas Kaleem
# Age: 22
# course: Ai & Data Science
# institute: Salyani

# %%
name ="Anas Kaleem"
department = "IT"
salary = "75000"
experience = "4 years"

print("Employee Profile")
print("name:", name)
print("department:", department)
print("salary:", salary)
print("experience:", experience)
# Out:
# Employee Profile
# name: Anas Kaleem
# department: IT
# salary: 75000
# experience: 4 years

# %%
product_name= ("Laptop")
price = ("125000")
quantity= ("150")

print("Product Information")
print("product name:", product_name)
print("price:", price)
print("quantity:", quantity)
# Out:
# Product Information
# product name: Laptop
# price: 125000
# quantity: 150

# %% [markdown]
# # Question#02

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")
course = input("Enter your course: ")

print("Personal Introduction")
print("My name is:", name)
print("I am:", age)
print("I live in:", city)
print("My Course is:", course)
# Out:
# Enter your name:  Anas Kaleem
# Enter your age:  22
# Enter your city:  Karchi
# Enter your course:  Ai and Data science
# Personal Introduction
# My name is: Anas Kaleem
# I am: 22
# I live in: Karchi
# My Course is: Ai and Data science

# %%
name = input("Enter your name: ")

print("Welcome", name,)
# Out:
# Enter your name:  Anas Kaleem
# Welcome Anas Kaleem

# %%
name_ = input("name")
roll_number = input("roll number")
course_ = input("course")
semester_ = input("semester")


print("My name is:", name_ )
print("My Roll Number is:", roll_number)
print("I Register in this course:", course_)
print("My Current Semester is:", semester_ )
# Out:
# name Anas Kaleem
# roll number 2023f-bse-316
# course Software Engineer
# semester 6
# My name is: Anas Kaleem
# My Roll Number is: 2023f-bse-316
# I Register in this course: Software Engineer
# My Current Semester is: 6

# %% [markdown]
# # Question#03

# %%
birth_year = int(input("Enter your birth year: "))

current_year = 2026
age = current_year - birth_year

print("Your approximate age is:", age)
# Out:
# Enter your birth year:  2004
# Your approximate age is: 22

# %%
product_price = int(input("Enter product price: "))
quantity = int(input("Enter quantity: "))

total_bill = product_price * quantity

print("Total bill:", total_bill)
# Out:
# Enter product price:  224
# Enter quantity:  200
# Total bill: 44800

# %%
celsius = float(input("Enter temperature in Celsius: "))

fahrenheit = (celsius * 9 / 5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius:  100
# Temperature in Fahrenheit: 212.0

# %%
Anas = int(input("Enter marks of Anas: "))
Jawad = int(input("Enter marks ofJawad: "))
Shayan = int(input("Enter marks of sShayan: "))

total = Anas + Jawad + Shayan
average = total / 3

print("Total marks:", total)
print("Average marks:", average)
# Out:
# Enter marks of Anas:  71
# Enter marks ofJawad:  89
# Enter marks of sShayan:  45
# Total marks: 205
# Average marks: 68.33333333333333

# %% [markdown]
# # Question#04

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

full_name = first_name + " " + last_name

print("Full Name:", full_name)
# Out:
# Enter your first name:  Anas
# Enter your last name:  Kaleem
# Full Name: Anas Kaleem

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

email = first_name +  last_name + "@gmail.com"

print("Email:", email)
# Out:
# Enter your first name:  Anas
# Enter your last name:  Kaleem
# Email: AnasKaleem@gmail.com

# %%
house_number = input("Enter your house number: ")
street = input("Enter your street: ")
city = input("Enter your city: ")

address = house_number + ", " + street + ", " + city

print("Address:", address)
# Out:
# Enter your house number:  house no.#344
# Enter your street:  Street#02
# Enter your city:  Karchi
# Address: house no.#344, Street#02, Karchi

# %% [markdown]
# # Question#05

# %%
symbol = input("Enter a symbol: ")
number = int(input("Enter the number of repetitions: "))

print(symbol * number)
# Out:
# Enter a symbol:  aaa
# Enter the number of repetitions:  24
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %% [markdown]
# # Question#06

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
# Out:
# Enter first number:  224
# Enter second number:  658
# Addition: 882
# Subtraction: -434
# Multiplication: 147392

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width
perimeter = 2 * (length + width)

print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Enter length:  64
# Enter width:  45.1
# Area: 2886.4
# Perimeter: 218.2

# %%
radius = float(input("Enter radius: "))

pi = 3.14159
area = pi * radius * radius
circumference = 2 * pi * radius

print("Area:", area)
print("Circumference:", circumference)
# Out:
# Enter radius:  24
# Area: 1809.5558399999998
# Circumference: 150.79631999999998

# %%
principal = int(input("Enter principal amount: "))
rate = int(input("Enter rate of interest: "))
time = int(input("Enter time in years: "))

simple_interest = (principal * rate * time) / 100

print("Simple Interest:", simple_interest)
# Out:
# Enter principal amount:  10000
# Enter rate of interest:  10
# Enter time in years:  5
# Simple Interest: 5000.0

# %%
price = int(input("Enter price: "))
quantity = int(input("Enter quantity: "))
discount_percent = int(input("Enter discount percentage: "))

subtotal = price * quantity
discount = subtotal * discount_percent / 100
final_price = subtotal - discount

print("Subtotal:", subtotal)
print("Discount:", discount)
print("Final Price:", final_price)
# Out:
# Enter price:  115
# Enter quantity:  5
# Enter discount percentage:  2
# Subtotal: 575
# Discount: 11.5
# Final Price: 563.5

# %% [markdown]
# # Question#07

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible.")
else:
    print("You are not eligible.")
# Out:
# Enter your age:  22
# You are eligible.

# %%
marks = float(input("Enter marks: "))

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  60
# Pass

# %% [markdown]
# # Question#08

# %%
age = int(input("Enter your age: "))
license = input("Do you have a driving license? (yes/no): ")

if age >= 18 and license == "yes":
    print("You are eligible to drive.")
else:
    print("You are not eligible to drive.")
# Out:
# Enter your age:  22
# Do you have a driving license? (yes/no):  yes
# You are eligible to drive.

# %%
marks = int(input("Enter your marks: "))
age = int(input("Enter your age: "))

if marks >= 50 and age >= 18:
    print("Admission allowed.")
else:
    print("Admission not allowed.")
# Out:
# Enter your marks:  55
# Enter your age:  22
# Admission allowed.

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login successful.")
else:
    print("Invalid username or password.")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login successful.

# %% [markdown]
# # Question#09

# %%
word = input("Enter a word: ")
character = input("Enter a character: ")

if character in word:
    print("Character exists in the word.")
else:
    print("Character does not exist in the word.")
# Out:
# Enter a word:  Pneumonoultramicroscopicsilicovolcanoconiosis
# Enter a character:  o
# Character exists in the word.

# %%
email = input("Enter your email: ")

if "@" in email:
    print("Valid email.")
else:
    print("Invalid email.")
# Out:
# Enter your email:  anuskaleem07@gmail.com
# Valid email.

# %%
sentence = input("Enter a sentence: ")

if "python" in sentence:
    print("The word 'python' exists in the sentence.")
else:
    print("The word 'python' does not exist in the sentence.")
# Out:
# Enter a sentence:  python is good
# The word 'python' exists in the sentence.
