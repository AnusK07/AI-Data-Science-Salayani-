# %% [markdown]
# # Question#01

# %%
num = float(input ("Enter your number:"))
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter your number: -55
# The number is negative.

# %% [markdown]
# # Question#02

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if num1 > num2:
    print("The larger number is:", num1)
elif num2 > num1:
    print("The larger number is:", num2)
else:
    print("Both numbers are equal.")
# Out:
# Enter first number:  22
# Enter second number:  66
# The larger number is: 66.0

# %% [markdown]
# # Question#03

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("The largest number is:", num1)
elif num2 >= num1 and num2 >= num3:
    print("The largest number is:", num2)
else:
    print("The largest number is:", num3)
# Out:
# Enter first number:  597
# Enter second number:  335
# Enter third number:  1000
# The largest number is: 1000.0

# %% [markdown]
# # Question#04

# %%
word = "Saylani Mass IT"

if "Mass" in word:
    print("string found")
# Out:
# string found

# %% [markdown]
# # Question#05

# %%
age = int(input("Enter your age: "))

if age < 18:
    print("Minor")
elif age > 18 and age < 60:
    print("Adult")
elif age > 60:
    print("Senior Citizen")
# Out:
# Enter your age:  22
# Adult

# %% [markdown]
# # Question#06

# %%
num = int(input("Enter an integer: "))

if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter an integer:  365
# The number is odd.

# %% [markdown]
# # Question#07

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operator (+, -, x, /): ")

if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "x":
    print("Result:", num1 * num2)
elif operator == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero.")
else:
    print("Invalid operator.")
# Out:
# Enter first number:  365
# Enter second number:  154225
# Enter operator (+, -, x, /):  /
# Result: 0.0023666720700275573

# %% [markdown]
# # Question#08

# %%
num = int(input("Enter a number: "))

if num >= 20 and num < 40:
    print("Number lies in the range 20 to 40.")
else:
    print("Number does not lie in the range.")
# Out:
# Enter a number:  27
# Number lies in the range 20 to 40.

# %% [markdown]
# # Question#09

# %%
num = int(input("Enter an integer: "))

if num % 2 == 0 and num % 3 == 0:
    print("The number is divisible by both 2 and 3.")
elif num % 2 == 0:
    print("The number is divisible by 2.")
elif num % 3 == 0:
    print("The number is divisible by 3.")
else:
    print("The number is not divisible by 2 or 3.")
# Out:
# Enter an integer:  35
# The number is not divisible by 2 or 3.

# %% [markdown]
# # Question#10

# %%
score = float(input("Enter your score: "))

if score > 60:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your score:  59.9
# Fail

# %% [markdown]
# # Question#11

# %%
temperature = float(input("Enter temperature in Celsius: "))

if temperature < 0:
    print("Freezing")
elif temperature > 0 and temperature < 26:
    print("Moderate")
elif temperature > 26:
    print("Hot")
else:
    print("Temperature is 0 or 26 degrees.")
# Out:
# Enter temperature in Celsius:  29
# Hot

# %% [markdown]
# # Question#12

# %%
salary = float(input("Enter your salary: Rs. "))

if salary > 600000:
    tax = salary * 0.05
    gross_salary = salary - tax
    print("Tax:", tax)
    print("Gross Salary:", gross_salary)
else:
    print("Gross Salary:", salary)
# Out:
# Enter your salary: Rs.  650000
# Tax: 32500.0
# Gross Salary: 617500.0

# %% [markdown]
# # Question#13

# %%
salary = float(input("Enter your salary: Rs. "))

if salary > 2500000:
    tax = salary * 0.15
elif salary >= 1500000:
    tax = salary * 0.10
elif salary >= 500000:
    tax = salary * 0.05
else:
    tax = 0

gross_salary = salary - tax

print("Tax Deduction: Rs.", tax)
print("Gross Salary: Rs.", gross_salary)
# Out:
# Enter your salary: Rs.  1500000
# Tax Deduction: Rs. 150000.0
# Gross Salary: Rs. 1350000.0
